# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import random
from scipy.optimize import curve_fit
from scipy.stats import norm

# %%
# Function Definitions

# Curve fitting part 
# define the true objective function ----------------------------------------------
def objective(x, a, b, c, d, e, f):
	return (a * x) + (b * x**2) + (c * x**3) + (d * x**4) + (e * x**5) + f

def objectiveSig(x, a, b):
    return 1. / (1 + np.exp( -((x-a)/b)))

def objectiveSig2(x, a, b, c, d):
    return 1. / (1 + np.exp(-((x*-a)/b)) + c * (np.exp(-((x-a)/b))) + d * (np.exp(-((x-a)/d))))

def objectiveSig3(x, a, b, c):
    return (a / (1 + np.exp((-b)*(x-c))))

def objectiveSig4(x, a, b, c):
    return (a * (1 - np.exp(-(x-c)/b)))

def psyFunction(x,mu,sd,k,offset):
    yhat = norm.cdf(x,mu, sd) * k + offset
    return yhat 

def func5(t,a,b,c,d,e,f):
        return a*pow(t,5)+b*pow(t,4)+c*pow(t,3)+d*pow(t,2)+e*t+f
    
def sigmoidFunc(x):
    1/(1 + np.exp(-x)) 

def objectivePol(x, a,b,c):
    return a*pow(x,2)+b*x+c
# --------------------------------------------------------------------------------------

def Create2DList(rows,cols,initVal):
    answrs=[]
    for j in range(rows):
        column = []
        for i in range(cols):
            column.append(initVal)
        answrs.append(column)
    return answrs


def Average(lst): 
    
    # Make sure no number 2s are included in the average
    if 2 in lst:
        lst.remove(2.0) 
    
    avrg = 0.0
    try:
        avrg = np.round(sum(lst) / len(lst),3)
    except Exception as e:
#         print(e)
        avrg = np.nan
    
    return avrg

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx, array[idx]

# %%
# path = "C:/Users/danhq/Desktop/VisualProprioceptive_Analaysis/Visual-Proprioceptive/VisualProprioceptive_Data/"
# path = "C:/Users/danhq/Desktop/VisualProprioceptive_Analaysis/Visual-Proprioceptive/VisualProprioceptive_Data/"
path = "D:/OneDrive/Documents/Projects/VisualProprioceptiveGithub/Visual-Proprioceptive/VisualProprioceptive_Data/"

# %%
# Analysis of the answers given after movement to the target was made (i.e. visual-proprioceptive condition)
files = os.listdir(path)

dataFrame = None 
correct = 0 #np.ones(len(files))
responseVal = 0

for i in range(len(files)):
    
    filez = "Answer" in files[i] 
        
    if filez:
        
        data = pd.read_csv(path + files[i],sep=':', header=[0,1,2])
#         data = pd.read_fwf(path + files[i],sep=':', header=[0,1,2])

#----------------------------------------------------------------------------
        fName = files[i]
        fNameS = fName.split('_')
#         print(fNameS)
#         print(float(fNameS[6]))
        
        try:
            propVal = float(fNameS[6])
        except Exception as e:
            print(e)
            replText = fNameS[6].replace("," , ".")
            print(replText)
            propVal = float(replText)
    
        targPos = data.iloc[0]["Name" == "Target_Position"]
        stiPos = data.iloc[1]["Name" == "Stimulus_Position"]
        reHPos = data.iloc[2]["Name" == "RealHand_Position"]
        stzPos = data.iloc[3]["Name" == "StartZone_Position"]
        resPos = data.iloc[4]["Name" == "Response"]
        
        if "Y" in resPos:
            responseVal = 1
        else:
            responseVal = 0
        
        tp = targPos.split(',')
        sp = stiPos.split(',')
        rep = reHPos.split(',')
        szP = stzPos.split(',')

        tpf =(float(tp[2]))
        spf = (float(sp[2]))
        rpf = (float(rep[2]))
        szf = (float(szP[2]))

        diffPos = np.absolute(tpf-spf)
        realVsVirtHand = np.absolute(rpf-spf)

#         print(round(result,4))
#         print(resPos)
    
    #-------------------------------------------------
    # if the proprioceptive value is positive and the answer is yes, then that is incorrect 
    # if the proprioceptive value is negative and the answer is yes, then that is correct 

        if propVal > 0.0 and 'Y' in resPos:
            correct = 0
        if propVal < 0.0 and 'Y' in resPos:
            correct = 1
        if propVal > 0.0 and 'N'in resPos:
            correct = 1
        if propVal < 0.0 and 'N' in resPos:
            correct = 0
        if propVal == 0.0:
            correct = 2

    #-------------------------------------------------
    
        rawValues = list((tpf,spf,rpf,szf,realVsVirtHand,propVal,diffPos,resPos,correct))
        tmpValues = pd.DataFrame([rawValues],columns=['TargetPos','StimulusPos','RealHandPos','StartZone','Real2VirtHandDiff','ProprioceptiveVal','Target2StimDiff','Response','Answer'])
        
        tmpValues.insert(0, "Trial", fNameS[7][0] , True)
        tmpValues.insert(0, "Participant_ID", fNameS[2] , True)
        
        if dataFrame is None:
            dataFrame = tmpValues
        else:
            dataFrame = pd.concat((dataFrame, tmpValues)) 
    
#----------------------------------------------------------------------------
# Out:
# ['1602405451', 'Answer', '379d850213', 'Trg', '0', 'Prop', '0.05', '0.txt']
# ['1602405455', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '1.txt']
# ['1602405460', 'Answer', '379d850213', 'Trg', '0', 'Prop', '-0.025', '2.txt']
# ['1602405463', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '-0.05', '3.txt']
# ['1602405466', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '0.025', '4.txt']
# ['1602405472', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0.1', '5.txt']
# ['1602795658', 'Answer', '379d850213', 'Trg', '0', 'Prop', '0.05', '0.txt']
# ['1602795663', 'Answer', '379d850213', 'Trg', '0', 'Prop', '-0.025', '1.txt']
# ['1602795667', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '-0.05', '2.txt']
# ['1602795670', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0.1', '3.txt']
# ['1602795673', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '0.025', '4.txt']
# ['1602795678', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '5.txt']
# ['1602795679', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '5.txt']
# ['1602795682', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '6.txt']
# ['1602957639', 'Answer', '379d850213', 'Trg', '0', 'Prop', '0.05', '0.txt']
# ['1602957642', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1602957647', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0.1', '2.txt']
# ['1602957651', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '3.txt']
# ['1602957652', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '3.txt']
# ['1602957655', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '-0.05', '4.txt']
# ['1602957658', 'Answer', '379d850213', 'Trg', '0', 'Prop', '-0.025', '5.txt']
# ['1602967114', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.025', '0.txt']
# ['1602967118', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.05', '1.txt']
# ['1602967123', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.1', '2.txt']
# ['1602967128', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0', '3.txt']
# ['1602967131', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.05', '4.txt']
# ['1602967135', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.025', '5.txt']
# ['1602971260', 'Answer', '379d850213', 'Trg', '0', 'Prop', '0.05', '0.txt']
# ['1602971264', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0', '1.txt']
# ['1602971268', 'Answer', '379d850213', 'Trg', '0.2', 'Prop', '0.1', '2.txt']
# ['1602971271', 'Answer', '379d850213', 'Trg', '0', 'Prop', '-0.025', '3.txt']
# ['1602971275', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '-0.05', '4.txt']
# ['1602971278', 'Answer', '379d850213', 'Trg', '-0.2', 'Prop', '0.025', '5.txt']
# ['1602973165', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.1', '0.txt']
# ['1602973185', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1602973190', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.05', '2.txt']
# ['1602973194', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.025', '3.txt']
# ['1602973197', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.05', '4.txt']
# ['1602973203', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0', '5.txt']
# ['1602975223', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.05', '0.txt']
# ['1602975231', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0', '1.txt']
# ['1602975236', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.025', '2.txt']
# ['1602975239', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.05', '3.txt']
# ['1602975245', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.05', '4.txt']
# ['1602975256', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0', '5.txt']
# ['1602975259', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.025', '6.txt']
# ['1602975264', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.1', '7.txt']
# ['1602975275', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0', '8.txt']
# ['1602975279', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.1', '9.txt']
# ['1602975283', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.1', '10.txt']
# ['1602975286', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.1', '11.txt']
# ['1602975287', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.1', '11.txt']
# ['1602975289', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.05', '12.txt']
# ['1602975293', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.025', '13.txt']
# ['1602975296', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.05', '14.txt']
# ['1602975309', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.025', '15.txt']
# ['1602975312', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.1', '16.txt']
# ['1602975315', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.025', '17.txt']
# ['1602975318', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.1', '18.txt']
# ['1602975322', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.05', '19.txt']
# ['1602975326', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '0.025', '20.txt']
# ['1602975330', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.025', '21.txt']
# ['1602975335', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.025', '22.txt']
# ['1602975339', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0', '23.txt']
# ['1602975343', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0', '24.txt']
# ['1602975346', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.1', '25.txt']
# ['1602975347', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.1', '25.txt']
# ['1602975350', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.1', '26.txt']
# ['1602975353', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '-0.05', '27.txt']
# ['1602975355', 'Answer', '6cde45c99c', 'Trg', '0', 'Prop', '0.05', '28.txt']
# ['1602975358', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.1', '29.txt']
# ['1602975362', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.025', '30.txt']
# ['1602975365', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.05', '31.txt']
# ['1602975369', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '-0.05', '32.txt']
# ['1602975372', 'Answer', '6cde45c99c', 'Trg', '-0.2', 'Prop', '-0.025', '33.txt']
# ['1602975375', 'Answer', '6cde45c99c', 'Trg', '0.2', 'Prop', '0.1', '34.txt']
# ['1603191884', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '-0.025', '0.txt']
# ['1603191899', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '-0.025', '1.txt']
# ['1603191903', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '-0.05', '2.txt']
# ['1603191911', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0', '3.txt']
# ['1603191915', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0', '4.txt']
# ['1603191918', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0.05', '5.txt']
# ['1603191922', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0.05', '6.txt']
# ['1603191925', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '-0.025', '7.txt']
# ['1603191929', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0.025', '8.txt']
# ['1603191933', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0.025', '9.txt']
# ['1603191936', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0.05', '10.txt']
# ['1603191939', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0.05', '11.txt']
# ['1603191943', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0.1', '12.txt']
# ['1603191946', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0.025', '13.txt']
# ['1603191949', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0.1', '14.txt']
# ['1603191956', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0.1', '15.txt']
# ['1603191959', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '-0.05', '16.txt']
# ['1603191966', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '-0.025', '17.txt']
# ['1603191968', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0.1', '18.txt']
# ['1603191973', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.025', '19.txt']
# ['1603191974', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.025', '19.txt']
# ['1603191976', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.05', '20.txt']
# ['1603191980', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0.025', '21.txt']
# ['1603191983', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.1', '22.txt']
# ['1603191986', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0', '23.txt']
# ['1603191989', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0.1', '24.txt']
# ['1603191993', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.1', '25.txt']
# ['1603191996', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '-0.05', '26.txt']
# ['1603192001', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '0.05', '27.txt']
# ['1603192004', 'Answer', '4f7f802b39', 'Trg', '0.2', 'Prop', '-0.05', '28.txt']
# ['1603192007', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '0', '29.txt']
# ['1603192011', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '-0.1', '30.txt']
# ['1603192014', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0', '31.txt']
# ['1603192018', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '-0.1', '32.txt']
# ['1603192021', 'Answer', '4f7f802b39', 'Trg', '-0.2', 'Prop', '0.025', '33.txt']
# ['1603192030', 'Answer', '4f7f802b39', 'Trg', '0', 'Prop', '-0.1', '34.txt']
# ['1603465803', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.1', '0.txt']
# ['1603465881', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1603465900', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1603465906', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.025', '3.txt']
# ['1603465907', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.025', '3.txt']
# ['1603465915', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '-0.05', '4.txt']
# ['1603465919', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '-0.1', '5.txt']
# ['1603465924', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '0', '6.txt']
# ['1603465928', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0.1', '7.txt']
# ['1603465933', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '-0.1', '8.txt']
# ['1603465940', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0.025', '9.txt']
# ['1603465946', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '-0.025', '10.txt']
# ['1603465952', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.05', '11.txt']
# ['1603465958', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.1', '12.txt']
# ['1603465965', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.1', '13.txt']
# ['1603465974', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0', '14.txt']
# ['1603465978', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.05', '15.txt']
# ['1603465982', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '0.025', '16.txt']
# ['1603465989', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0', '17.txt']
# ['1603465994', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.1', '18.txt']
# ['1603465999', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.05', '19.txt']
# ['1603466003', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '0.05', '20.txt']
# ['1603466008', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.025', '21.txt']
# ['1603466014', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '0.1', '22.txt']
# ['1603466019', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '-0.025', '23.txt']
# ['1603466023', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '-0.05', '24.txt']
# ['1603466026', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '0.05', '25.txt']
# ['1603466030', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.025', '26.txt']
# ['1603466034', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '-0.05', '27.txt']
# ['1603466038', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '-0.1', '28.txt']
# ['1603466042', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0', '29.txt']
# ['1603466046', 'Answer', '08727a345f', 'Trg', '0.2', 'Prop', '0.025', '30.txt']
# ['1603466050', 'Answer', '08727a345f', 'Trg', '-0.2', 'Prop', '-0.05', '31.txt']
# ['1603466053', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0', '32.txt']
# ['1603466059', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.05', '33.txt']
# ['1603466063', 'Answer', '08727a345f', 'Trg', '0', 'Prop', '0.025', '34.txt']
# ['1603471537', 'Answer', '59ddec312e', 'Trg', '0', 'Prop', '0', '0.txt']
# ['1603471560', 'Answer', '59ddec312e', 'Trg', '0.2', 'Prop', '0', '1.txt']
# ['1606823157', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.1', '0.txt']
# ['1606823174', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.025', '1.txt']
# ['1606823187', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0', '2.txt']
# ['1606823199', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0', '3.txt']
# ['1606823206', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.05', '4.txt']
# ['1606823212', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.1', '5.txt']
# ['1606823216', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '0.1', '6.txt']
# ['1606823223', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0.05', '7.txt']
# ['1606823230', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0.025', '8.txt']
# ['1606823238', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.05', '9.txt']
# ['1606823249', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0.1', '10.txt']
# ['1606823254', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '-0.05', '11.txt']
# ['1606823260', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '-0.1', '12.txt']
# ['1606823274', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '0', '14.txt']
# ['1606823282', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0.05', '15.txt']
# ['1606823286', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '-0.1', '16.txt']
# ['1606823290', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '-0.05', '17.txt']
# ['1606823293', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '-0.1', '18.txt']
# ['1606823296', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '-0.025', '19.txt']
# ['1606823297', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '-0.025', '19.txt']
# ['1606823301', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '-0.05', '20.txt']
# ['1606823306', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '0', '21.txt']
# ['1606823309', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0', '22.txt']
# ['1606823312', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '0.025', '23.txt']
# ['1606823316', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '-0.05', '24.txt']
# ['1606823320', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '0.025', '25.txt']
# ['1606823323', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '-0.025', '26.txt']
# ['1606823327', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '-0.1', '27.txt']
# ['1606823332', 'Answer', '7b72e7a577', 'Trg', '0.2', 'Prop', '-0.05', '28.txt']
# ['1606823335', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '-0.1', '29.txt']
# ['1606823342', 'Answer', '7b72e7a577', 'Trg', '-0.2', 'Prop', '0.1', '31.txt']
# ['1606823345', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '-0.025', '32.txt']
# ['1606823348', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '-0.025', '33.txt']
# ['1606823351', 'Answer', '7b72e7a577', 'Trg', '0', 'Prop', '0.025', '34.txt']
# ['1608984572', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0', '0.txt']
# ['1608984643', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,1', '1.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984706', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,025', '2.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984707', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,025', '2.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984707', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,025', '3.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984715', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,025', '2.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984717', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,025', '3.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984723', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,1', '4.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984725', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,1', '4.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984730', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,025', '5.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984731', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,025', '5.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984739', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0', '6.txt']
# ['1608984741', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0', '7.txt']
# ['1608984742', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0', '7.txt']
# ['1608984746', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '-0,05', '8.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984750', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0', '9.txt']
# ['1608984757', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,05', '10.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984758', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,05', '10.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984762', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,05', '11.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984766', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,05', '12.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984769', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0', '13.txt']
# ['1608984777', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,1', '14.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1608984778', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,05', '15.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984783', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,025', '16.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984787', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,1', '17.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984792', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,025', '18.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984793', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,025', '18.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984798', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '-0,1', '19.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984801', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,05', '20.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984802', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,05', '20.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984804', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,1', '21.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984805', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '-0,1', '21.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1608984808', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,05', '22.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984811', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '-0,025', '23.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984815', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,025', '24.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984820', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,025', '25.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1608984822', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '-0,025', '26.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984828', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,1', '27.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1608984830', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,05', '28.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984834', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '-0,05', '29.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1608984838', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,1', '30.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1608984842', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '0,1', '31.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1608984846', 'Answer', 'ea31d92230', 'Trg', '0,2', 'Prop', '0,05', '32.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1608984853', 'Answer', 'ea31d92230', 'Trg', '0', 'Prop', '-0,025', '33.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1608984860', 'Answer', 'ea31d92230', 'Trg', '-0,2', 'Prop', '0,1', '34.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609114076', 'Answer', '57146a73e9', 'Trg', '0.2', 'Prop', '-0.1', '0.txt']
# ['1609168283', 'Answer', '7176b229fa', 'Trg', '-0.2', 'Prop', '-0.05', '0.txt']
# ['1609168292', 'Answer', '7176b229fa', 'Trg', '-0.2', 'Prop', '0.1', '1.txt']
# ['1609428883', 'Answer', '1953ebb14a', 'Trg', '-0,2', 'Prop', '-0,1', '0.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609428913', 'Answer', '1953ebb14a', 'Trg', '0,2', 'Prop', '0,1', '1.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609428914', 'Answer', '1953ebb14a', 'Trg', '0,2', 'Prop', '0,1', '1.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609428917', 'Answer', '1953ebb14a', 'Trg', '0,2', 'Prop', '-0,025', '2.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609450346', 'Answer', 'ae7b6a32ca', 'Trg', '0.2', 'Prop', '0', '0.txt']
# ['1609450418', 'Answer', 'ae7b6a32ca', 'Trg', '0', 'Prop', '0', '1.txt']
# ['1609450458', 'Answer', 'ae7b6a32ca', 'Trg', '0.2', 'Prop', '0.1', '2.txt']
# ['1609450471', 'Answer', 'ae7b6a32ca', 'Trg', '0.2', 'Prop', '0.05', '3.txt']
# ['1609450479', 'Answer', 'ae7b6a32ca', 'Trg', '0', 'Prop', '0.1', '4.txt']
# ['1609450487', 'Answer', 'ae7b6a32ca', 'Trg', '0.2', 'Prop', '-0.1', '5.txt']
# ['1609450493', 'Answer', 'ae7b6a32ca', 'Trg', '-0.2', 'Prop', '0.05', '6.txt']
# ['1609450498', 'Answer', 'ae7b6a32ca', 'Trg', '0.2', 'Prop', '-0.1', '7.txt']
# ['1609505588', 'Answer', '050fcbd4b9', 'Trg', '-0.2', 'Prop', '-0.1', '0.txt']
# ['1609505666', 'Answer', '050fcbd4b9', 'Trg', '-0.2', 'Prop', '-0.05', '1.txt']
# ['1609505677', 'Answer', '050fcbd4b9', 'Trg', '-0.2', 'Prop', '-0.05', '1.txt']
# ['1609543088', 'Answer', 'dd491641a5', 'Trg', '0.2', 'Prop', '-0.025', '0.txt']
# ['1609543106', 'Answer', 'dd491641a5', 'Trg', '0.2', 'Prop', '0.025', '1.txt']
# ['1609543119', 'Answer', 'dd491641a5', 'Trg', '-0.2', 'Prop', '-0.05', '2.txt']
# ['1609543127', 'Answer', 'dd491641a5', 'Trg', '0', 'Prop', '-0.025', '3.txt']
# ['1609543141', 'Answer', 'dd491641a5', 'Trg', '0.2', 'Prop', '0', '4.txt']
# ['1609543151', 'Answer', 'dd491641a5', 'Trg', '-0.2', 'Prop', '-0.025', '5.txt']
# ['1609543157', 'Answer', 'dd491641a5', 'Trg', '0.2', 'Prop', '0', '6.txt']
# ['1609543164', 'Answer', 'dd491641a5', 'Trg', '-0.2', 'Prop', '0.05', '7.txt']
# ['1609543174', 'Answer', 'dd491641a5', 'Trg', '-0.2', 'Prop', '0.1', '8.txt']
# ['1609543179', 'Answer', 'dd491641a5', 'Trg', '0', 'Prop', '-0.1', '9.txt']
# ['1609543185', 'Answer', 'dd491641a5', 'Trg', '0', 'Prop', '0.1', '10.txt']
# ['1609549896', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '-0.05', '0.txt']
# ['1609549960', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '-0.1', '1.txt']
# ['1609549983', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.05', '2.txt']
# ['1609549984', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.05', '2.txt']
# ['1609550016', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0.025', '3.txt']
# ['1609550017', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0.025', '3.txt']
# ['1609550054', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0.05', '4.txt']
# ['1609550084', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '-0.025', '5.txt']
# ['1609550085', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '-0.025', '5.txt']
# ['1609550094', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.025', '6.txt']
# ['1609550102', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '-0.1', '7.txt']
# ['1609550105', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0.05', '8.txt']
# ['1609550109', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.025', '9.txt']
# ['1609550114', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0.05', '10.txt']
# ['1609550118', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.025', '11.txt']
# ['1609550129', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0', '12.txt']
# ['1609550135', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '-0.1', '13.txt']
# ['1609550138', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.05', '14.txt']
# ['1609550142', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '-0.025', '15.txt']
# ['1609550148', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0.1', '16.txt']
# ['1609550161', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0', '17.txt']
# ['1609550167', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.025', '18.txt']
# ['1609550171', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0.025', '19.txt']
# ['1609550175', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.1', '20.txt']
# ['1609550181', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0.1', '21.txt']
# ['1609550186', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.05', '22.txt']
# ['1609550189', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '-0.1', '23.txt']
# ['1609550192', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0.1', '24.txt']
# ['1609550196', 'Answer', '2443e3c455', 'Trg', '0', 'Prop', '0', '25.txt']
# ['1609550201', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.05', '26.txt']
# ['1609550205', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '-0.05', '27.txt']
# ['1609550210', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.025', '28.txt']
# ['1609550214', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.05', '29.txt']
# ['1609550218', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0', '30.txt']
# ['1609550222', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.1', '31.txt']
# ['1609550225', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '0.1', '32.txt']
# ['1609550235', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '-0.025', '33.txt']
# ['1609550236', 'Answer', '2443e3c455', 'Trg', '0.2', 'Prop', '-0.025', '33.txt']
# ['1609550256', 'Answer', '2443e3c455', 'Trg', '-0.2', 'Prop', '0', '34.txt']
# ['1609602014', 'Answer', 'bede2a792f', 'Trg', '0,2', 'Prop', '-0,025', '0.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609613003', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.05', '0.txt']
# ['1609613084', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0', '1.txt']
# ['1609613104', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0', '2.txt']
# ['1609613115', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '-0.1', '3.txt']
# ['1609613127', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '-0.025', '4.txt']
# ['1609613133', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '-0.1', '5.txt']
# ['1609613140', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0', '6.txt']
# ['1609613151', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0.05', '7.txt']
# ['1609613158', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '-0.05', '8.txt']
# ['1609613167', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.05', '9.txt']
# ['1609613174', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '-0.05', '10.txt']
# ['1609613185', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0.025', '11.txt']
# ['1609613199', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0.1', '12.txt']
# ['1609613210', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0', '13.txt']
# ['1609613217', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0.1', '14.txt']
# ['1609613232', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '-0.05', '15.txt']
# ['1609613240', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0.05', '16.txt']
# ['1609613248', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0', '17.txt']
# ['1609613253', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.05', '18.txt']
# ['1609613259', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '-0.025', '19.txt']
# ['1609613265', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.025', '20.txt']
# ['1609613269', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.025', '21.txt']
# ['1609613278', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '-0.025', '22.txt']
# ['1609613282', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '-0.1', '23.txt']
# ['1609613287', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '0.025', '24.txt']
# ['1609613292', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '-0.05', '25.txt']
# ['1609613297', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '-0.1', '26.txt']
# ['1609613302', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0.025', '27.txt']
# ['1609613309', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0.1', '28.txt']
# ['1609613313', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '0.1', '29.txt']
# ['1609613318', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '-0.05', '30.txt']
# ['1609613323', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '-0.025', '31.txt']
# ['1609613326', 'Answer', '83ea3b75be', 'Trg', '0', 'Prop', '-0.025', '32.txt']
# ['1609613330', 'Answer', '83ea3b75be', 'Trg', '0.2', 'Prop', '0.1', '33.txt']
# ['1609613333', 'Answer', '83ea3b75be', 'Trg', '-0.2', 'Prop', '-0.1', '34.txt']
# ['1609626669', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '-0.05', '0.txt']
# ['1609626716', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0.05', '1.txt']
# ['1609626742', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '-0.1', '3.txt']
# ['1609626749', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0.1', '4.txt']
# ['1609626760', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0.1', '5.txt']
# ['1609626767', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '-0.1', '6.txt']
# ['1609626779', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0', '7.txt']
# ['1609626783', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0', '8.txt']
# ['1609626789', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0.1', '9.txt']
# ['1609626792', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '-0.1', '10.txt']
# ['1609626798', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0.05', '11.txt']
# ['1609626801', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0.025', '12.txt']
# ['1609626805', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '-0.1', '13.txt']
# ['1609626809', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '-0.025', '14.txt']
# ['1609626812', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '-0.05', '15.txt']
# ['1609626818', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '-0.05', '16.txt']
# ['1609626821', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '-0.025', '17.txt']
# ['1609626825', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '-0.05', '18.txt']
# ['1609626829', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0.025', '19.txt']
# ['1609626833', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '-0.025', '20.txt']
# ['1609626836', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0.025', '21.txt']
# ['1609626843', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0.025', '22.txt']
# ['1609626846', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0', '23.txt']
# ['1609626849', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '-0.05', '24.txt']
# ['1609626852', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '0.05', '25.txt']
# ['1609626855', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0', '26.txt']
# ['1609626858', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0', '27.txt']
# ['1609626861', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '-0.1', '28.txt']
# ['1609626864', 'Answer', '331a150c14', 'Trg', '0', 'Prop', '-0.025', '29.txt']
# ['1609626867', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '-0.025', '30.txt']
# ['1609626871', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0.05', '31.txt']
# ['1609626875', 'Answer', '331a150c14', 'Trg', '0.2', 'Prop', '0.025', '32.txt']
# ['1609626878', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0.1', '33.txt']
# ['1609626881', 'Answer', '331a150c14', 'Trg', '-0.2', 'Prop', '0.05', '34.txt']
# ['1609679191', 'Answer', 'c4fc81dfac', 'Trg', '0.2', 'Prop', '-0.025', '0.txt']
# ['1609679209', 'Answer', 'c4fc81dfac', 'Trg', '-0.2', 'Prop', '-0.05', '1.txt']
# ['1609679210', 'Answer', 'c4fc81dfac', 'Trg', '-0.2', 'Prop', '-0.05', '1.txt']
# ['1609679218', 'Answer', 'c4fc81dfac', 'Trg', '-0.2', 'Prop', '0.05', '2.txt']
# ['1609679233', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '-0.025', '3.txt']
# ['1609679241', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '-0.1', '4.txt']
# ['1609679249', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '0.05', '5.txt']
# ['1609679255', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '0.1', '6.txt']
# ['1609679260', 'Answer', 'c4fc81dfac', 'Trg', '-0.2', 'Prop', '-0.05', '7.txt']
# ['1609679265', 'Answer', 'c4fc81dfac', 'Trg', '0.2', 'Prop', '0.05', '8.txt']
# ['1609679272', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '0.025', '9.txt']
# ['1609679279', 'Answer', 'c4fc81dfac', 'Trg', '0', 'Prop', '-0.1', '10.txt']
# ['1609679285', 'Answer', 'c4fc81dfac', 'Trg', '0.2', 'Prop', '-0.05', '11.txt']
# ['1609679289', 'Answer', 'c4fc81dfac', 'Trg', '-0.2', 'Prop', '-0.1', '12.txt']
# ['1609697671', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,05', '0.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697747', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,025', '1.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697790', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,1', '2.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697797', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0,025', '3.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1609697802', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,025', '4.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1609697815', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,05', '5.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697819', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0', '6.txt']
# ['1609697820', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0', '7.txt']
# ['1609697824', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0', '7.txt']
# ['1609697828', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,05', '8.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697832', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,05', '9.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697833', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,05', '10.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697836', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,05', '10.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697836', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,1', '11.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697840', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,1', '11.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697843', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,05', '12.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697844', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,1', '13.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697857', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,1', '13.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697862', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0,1', '14.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697867', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0,1', '15.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697871', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,1', '16.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697874', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '0,025', '17.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1609697874', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,1', '18.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697877', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,1', '18.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697881', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0,1', '19.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1609697884', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0,05', '20.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697885', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,025', '21.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697888', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,025', '21.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697902', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0', '22.txt']
# ['1609697911', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '0', '23.txt']
# ['1609697914', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0,025', '24.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1609697918', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,025', '25.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697922', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0', '26.txt']
# ['1609697923', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,025', '27.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697925', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,025', '27.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697928', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,025', '28.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697929', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,025', '28.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1609697934', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '-0,05', '29.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697935', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,05', '30.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697948', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,05', '30.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1609697953', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0,05', '31.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1609697956', 'Answer', '61325914d1', 'Trg', '0', 'Prop', '0,025', '32.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1609697957', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,1', '33.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697959', 'Answer', '61325914d1', 'Trg', '-0,2', 'Prop', '-0,1', '33.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697959', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,1', '34.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609697963', 'Answer', '61325914d1', 'Trg', '0,2', 'Prop', '-0,1', '34.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1609710864', 'Answer', '32619578cd', 'Trg', '-0.2', 'Prop', '0.05', '0.txt']
# ['1609712655', 'Answer', '2af7e49a96', 'Trg', '-0.2', 'Prop', '0.025', '0.txt']
# ['1609712676', 'Answer', '2af7e49a96', 'Trg', '0.2', 'Prop', '0', '1.txt']
# ['1609715679', 'Answer', '7c42d20493', 'Trg', '0.2', 'Prop', '0.05', '0.txt']
# ['1609715712', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '0', '1.txt']
# ['1609715722', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '0.05', '2.txt']
# ['1609715737', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '-0.025', '3.txt']
# ['1609715742', 'Answer', '7c42d20493', 'Trg', '0', 'Prop', '-0.05', '4.txt']
# ['1609715756', 'Answer', '7c42d20493', 'Trg', '0', 'Prop', '-0.025', '5.txt']
# ['1609715761', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '-0.05', '6.txt']
# ['1609715766', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '-0.05', '7.txt']
# ['1609715771', 'Answer', '7c42d20493', 'Trg', '0', 'Prop', '-0.1', '8.txt']
# ['1609715775', 'Answer', '7c42d20493', 'Trg', '0.2', 'Prop', '0.1', '9.txt']
# ['1609715782', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '0.025', '10.txt']
# ['1609715787', 'Answer', '7c42d20493', 'Trg', '-0.2', 'Prop', '0.1', '11.txt']
# ['1609715791', 'Answer', '7c42d20493', 'Trg', '0.2', 'Prop', '-0.1', '12.txt']
# ['1609715797', 'Answer', '7c42d20493', 'Trg', '0.2', 'Prop', '0', '13.txt']
# ['1609736872', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '-0.05', '0.txt']
# ['1609736945', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '-0.025', '1.txt']
# ['1609736963', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '-0.025', '2.txt']
# ['1609736993', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '-0.1', '3.txt']
# ['1609737010', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.1', '4.txt']
# ['1609737021', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0', '5.txt']
# ['1609737056', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0.1', '6.txt']
# ['1609737074', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0.05', '7.txt']
# ['1609737089', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0.1', '8.txt']
# ['1609737098', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '-0.05', '9.txt']
# ['1609737113', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '-0.05', '10.txt']
# ['1609737131', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.025', '11.txt']
# ['1609737144', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0.05', '12.txt']
# ['1609737160', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0.025', '13.txt']
# ['1609737171', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '-0.05', '14.txt']
# ['1609737200', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0', '15.txt']
# ['1609737214', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '-0.1', '16.txt']
# ['1609737223', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0', '17.txt']
# ['1609737269', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0.1', '18.txt']
# ['1609737289', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0.025', '19.txt']
# ['1609737311', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0', '20.txt']
# ['1609737318', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '-0.1', '21.txt']
# ['1609737422', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '-0.025', '22.txt']
# ['1609737422', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.1', '23.txt']
# ['1609737435', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.1', '23.txt']
# ['1609737450', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '-0.025', '24.txt']
# ['1609737465', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '-0.1', '25.txt']
# ['1609737484', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '-0.025', '26.txt']
# ['1609737498', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0.05', '27.txt']
# ['1609737582', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0.025', '28.txt']
# ['1609737582', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0', '29.txt']
# ['1609737601', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '0', '29.txt']
# ['1609737608', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.05', '30.txt']
# ['1609737615', 'Answer', '5f08497baa', 'Trg', '0', 'Prop', '0.05', '31.txt']
# ['1609737619', 'Answer', '5f08497baa', 'Trg', '0.2', 'Prop', '-0.1', '32.txt']
# ['1609737626', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '0.025', '33.txt']
# ['1609737629', 'Answer', '5f08497baa', 'Trg', '-0.2', 'Prop', '-0.05', '34.txt']
# ['1609878638', 'Answer', 'd2866289bf', 'Trg', '-0.2', 'Prop', '-0.05', '0.txt']
# ['1609878727', 'Answer', 'd2866289bf', 'Trg', '0.2', 'Prop', '-0.025', '1.txt']
# ['1609878790', 'Answer', 'd2866289bf', 'Trg', '-0.2', 'Prop', '0.1', '2.txt']
# ['1609878808', 'Answer', 'd2866289bf', 'Trg', '0.2', 'Prop', '-0.1', '3.txt']
# ['1609878823', 'Answer', 'd2866289bf', 'Trg', '-0.2', 'Prop', '-0.025', '4.txt']
# ['1609878839', 'Answer', 'd2866289bf', 'Trg', '-0.2', 'Prop', '-0.1', '5.txt']
# ['1609878851', 'Answer', 'd2866289bf', 'Trg', '0', 'Prop', '0.025', '6.txt']
# ['1609878856', 'Answer', 'd2866289bf', 'Trg', '-0.2', 'Prop', '0.025', '7.txt']
# ['1609878863', 'Answer', 'd2866289bf', 'Trg', '0', 'Prop', '0', '8.txt']
# ['1609889816', 'Answer', 'ebc145976d', 'Trg', '-0.2', 'Prop', '-0.1', '0.txt']
# ['1610038456', 'Answer', 'bede2a792f', 'Trg', '0', 'Prop', '-0,1', '0.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1610106931', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0.025', '0.txt']
# ['1610107021', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1610107071', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.05', '3.txt']
# ['1610107071', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0', '2.txt']
# ['1610107089', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.05', '3.txt']
# ['1610107109', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0.1', '4.txt']
# ['1610107130', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0.025', '5.txt']
# ['1610107140', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.025', '6.txt']
# ['1610107145', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '-0.05', '7.txt']
# ['1610107152', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0.1', '8.txt']
# ['1610107160', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0.05', '9.txt']
# ['1610107167', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0.025', '10.txt']
# ['1610107174', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.05', '11.txt']
# ['1610107179', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '-0.025', '12.txt']
# ['1610107183', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0', '13.txt']
# ['1610107190', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.1', '14.txt']
# ['1610107198', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.05', '15.txt']
# ['1610107202', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '-0.025', '16.txt']
# ['1610107205', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '-0.1', '17.txt']
# ['1610107208', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '-0.1', '18.txt']
# ['1610107211', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0', '19.txt']
# ['1610107219', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0', '21.txt']
# ['1610107222', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.1', '22.txt']
# ['1610107225', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0.1', '23.txt']
# ['1610107229', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0.05', '24.txt']
# ['1610107234', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0.05', '25.txt']
# ['1610107236', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0.05', '26.txt']
# ['1610107240', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '0.025', '27.txt']
# ['1610107243', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.025', '28.txt']
# ['1610107247', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0.05', '29.txt']
# ['1610107251', 'Answer', 'd55f5603f6', 'Trg', '0', 'Prop', '0.1', '30.txt']
# ['1610107255', 'Answer', 'd55f5603f6', 'Trg', '-0.2', 'Prop', '-0.025', '31.txt']
# ['1610107258', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.05', '32.txt']
# ['1610107264', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '0', '33.txt']
# ['1610107265', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.1', '34.txt']
# ['1610107267', 'Answer', 'd55f5603f6', 'Trg', '0.2', 'Prop', '-0.1', '34.txt']
# ['1610142858', 'Answer', '453bf8b442', 'Trg', '0.2', 'Prop', '0.025', '0.txt']
# ['1610142885', 'Answer', '453bf8b442', 'Trg', '-0.2', 'Prop', '-0.05', '2.txt']
# ['1610142904', 'Answer', '453bf8b442', 'Trg', '-0.2', 'Prop', '0', '3.txt']
# ['1610142914', 'Answer', '453bf8b442', 'Trg', '-0.2', 'Prop', '-0.025', '4.txt']
# ['1610161499', 'Answer', 'df31100188', 'Trg', '-0.2', 'Prop', '-0.1', '0.txt']
# ['1610195553', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0,1', '0.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1610195587', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0,05', '1.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1610195595', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0,025', '2.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1610195601', 'Answer', 'ff97977261', 'Trg', '-0,2', 'Prop', '0,05', '3.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1610195608', 'Answer', 'ff97977261', 'Trg', '0,2', 'Prop', '0', '4.txt']
# ['1610195610', 'Answer', 'ff97977261', 'Trg', '-0,2', 'Prop', '0', '5.txt']
# ['1610195617', 'Answer', 'ff97977261', 'Trg', '0,2', 'Prop', '-0,05', '6.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1610195621', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0,05', '7.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1610195629', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '-0,1', '8.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1610195632', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '-0,025', '9.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1610195637', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0', '10.txt']
# ['1610195642', 'Answer', 'ff97977261', 'Trg', '0', 'Prop', '0,1', '11.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1610219698', 'Answer', '60603f4950', 'Trg', '0', 'Prop', '0', '0.txt']
# ['1610219826', 'Answer', '60603f4950', 'Trg', '0,2', 'Prop', '0', '1.txt']
# ['1610219858', 'Answer', '60603f4950', 'Trg', '0', 'Prop', '-0,05', '2.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1610219869', 'Answer', '60603f4950', 'Trg', '-0,2', 'Prop', '-0,025', '3.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1610219877', 'Answer', '60603f4950', 'Trg', '0,2', 'Prop', '-0,025', '4.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1610219885', 'Answer', '60603f4950', 'Trg', '-0,2', 'Prop', '0,1', '5.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1610219889', 'Answer', '60603f4950', 'Trg', '-0,2', 'Prop', '0,025', '6.txt']
# could not convert string to float: '0,025'
# 0.025
# ...
# ['1611699633', 'Answer', 'b53c727b6e', 'Trg', '0.2', 'Prop', '-0.1', '25.txt']
# ['1611699635', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '0.025', '19.txt']
# ['1611699637', 'Answer', 'b53c727b6e', 'Trg', '0.2', 'Prop', '-0.1', '26.txt']
# ['1611699640', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '0.05', '27.txt']
# ['1611699643', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '-0.025', '29.txt']
# ['1611699643', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '-0.1', '28.txt']
# ['1611699649', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '-0.025', '29.txt']
# ['1611699649', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '-0.025', '30.txt']
# ['1611699650', 'Answer', 'b53c727b6e', 'Trg', '0.2', 'Prop', '0.025', '31.txt']
# ['1611699653', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '-0.05', '32.txt']
# ['1611699653', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '0.1', '33.txt']
# ['1611699654', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '-0.025', '30.txt']
# ['1611699655', 'Answer', 'b53c727b6e', 'Trg', '0', 'Prop', '0.1', '33.txt']
# ['1611699656', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '0', '34.txt']
# ['1611699660', 'Answer', 'b53c727b6e', 'Trg', '-0.2', 'Prop', '0', '34.txt']
# ['1611746497', 'Answer', 'f2d27f8cf6', 'Trg', '0,2', 'Prop', '-0,1', '0.txt']
# could not convert string to float: '-0,1'
# -0.1
# ['1611746514', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '0', '1.txt']
# ['1611746523', 'Answer', 'f2d27f8cf6', 'Trg', '0', 'Prop', '0,05', '2.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1611746529', 'Answer', 'f2d27f8cf6', 'Trg', '0', 'Prop', '-0,05', '3.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1611746533', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '0,1', '4.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1611746534', 'Answer', 'f2d27f8cf6', 'Trg', '0,2', 'Prop', '-0,025', '5.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1611746537', 'Answer', 'f2d27f8cf6', 'Trg', '0,2', 'Prop', '-0,025', '5.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1611746539', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '0,05', '6.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1611746542', 'Answer', 'f2d27f8cf6', 'Trg', '0', 'Prop', '0,05', '7.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1611746548', 'Answer', 'f2d27f8cf6', 'Trg', '0,2', 'Prop', '-0,05', '8.txt']
# could not convert string to float: '-0,05'
# -0.05
# ['1611746562', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '0,025', '9.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1611746565', 'Answer', 'f2d27f8cf6', 'Trg', '0', 'Prop', '0,1', '10.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1611746574', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '0,05', '11.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1611746587', 'Answer', 'f2d27f8cf6', 'Trg', '-0,2', 'Prop', '-0,025', '12.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1611780289', 'Answer', '04f982d1b0', 'Trg', '-0.2', 'Prop', '0.025', '0.txt']
# ['1611780323', 'Answer', '04f982d1b0', 'Trg', '-0.2', 'Prop', '-0.025', '1.txt']
# ['1611780324', 'Answer', '04f982d1b0', 'Trg', '-0.2', 'Prop', '-0.025', '1.txt']
# ['1611780350', 'Answer', '04f982d1b0', 'Trg', '-0.2', 'Prop', '-0.025', '3.txt']
# ['1611780350', 'Answer', '04f982d1b0', 'Trg', '0', 'Prop', '-0.05', '4.txt']
# ['1611815891', 'Answer', 'cb563e0527', 'Trg', '-0.2', 'Prop', '0.025', '0.txt']
# ['1611815912', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '-0.1', '2.txt']
# ['1611815926', 'Answer', 'cb563e0527', 'Trg', '0', 'Prop', '-0.025', '3.txt']
# ['1611815934', 'Answer', 'cb563e0527', 'Trg', '0', 'Prop', '-0.025', '4.txt']
# ['1611815949', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '0.05', '5.txt']
# ['1611815956', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '0.1', '6.txt']
# ['1611815962', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '0.025', '7.txt']
# ['1611815981', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '-0.05', '8.txt']
# ['1611815982', 'Answer', 'cb563e0527', 'Trg', '0.2', 'Prop', '-0.05', '8.txt']
# ['1611863105', 'Answer', 'c5f93b83a1', 'Trg', '0,2', 'Prop', '0', '0.txt']
# ['1611863117', 'Answer', 'c5f93b83a1', 'Trg', '0', 'Prop', '0', '1.txt']
# ['1611930310', 'Answer', '89ea25ddd6', 'Trg', '0', 'Prop', '0,1', '0.txt']
# could not convert string to float: '0,1'
# 0.1
# ['1611930329', 'Answer', '89ea25ddd6', 'Trg', '0', 'Prop', '0', '2.txt']
# ['1611931703', 'Answer', '89ea25ddd6', 'Trg', '-0,2', 'Prop', '0,05', '0.txt']
# could not convert string to float: '0,05'
# 0.05
# ['1611945355', 'Answer', '42d6f27239', 'Trg', '-0.2', 'Prop', '0.05', '0.txt']
# ['1612063410', 'Answer', '335e0cfb09', 'Trg', '0', 'Prop', '0.025', '0.txt']
# ['1612074573', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '-0.025', '0.txt']
# ['1612074594', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.05', '1.txt']
# ['1612074604', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '-0.1', '2.txt']
# ['1612074618', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.05', '3.txt']
# ['1612074630', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0', '4.txt']
# ['1612074639', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.025', '5.txt']
# ['1612074640', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.025', '5.txt']
# ['1612074646', 'Answer', '68f00d7ff3', 'Trg', '-0.2', 'Prop', '-0.025', '6.txt']
# ['1612074650', 'Answer', '68f00d7ff3', 'Trg', '-0.2', 'Prop', '-0.025', '7.txt']
# ['1612074658', 'Answer', '68f00d7ff3', 'Trg', '-0.2', 'Prop', '-0.05', '8.txt']
# ['1612074666', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.1', '9.txt']
# ['1612074673', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '0.025', '10.txt']
# ['1612074679', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '0', '11.txt']
# ['1612074685', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '-0.1', '12.txt']
# ['1612074694', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '-0.05', '14.txt']
# ['1612074698', 'Answer', '68f00d7ff3', 'Trg', '-0.2', 'Prop', '0.025', '15.txt']
# ['1612074702', 'Answer', '68f00d7ff3', 'Trg', '0', 'Prop', '0.1', '16.txt']
# ['1612074706', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '0', '17.txt']
# ['1612074712', 'Answer', '68f00d7ff3', 'Trg', '0.2', 'Prop', '0.1', '18.txt']
# ['1612106720', 'Answer', 'b1e944d0a9', 'Trg', '-0,2', 'Prop', '-0,025', '0.txt']
# could not convert string to float: '-0,025'
# -0.025
# ['1612106742', 'Answer', 'b1e944d0a9', 'Trg', '0', 'Prop', '0,025', '1.txt']
# could not convert string to float: '0,025'
# 0.025
# ['1612130480', 'Answer', '02784557eb', 'Trg', '0.2', 'Prop', '0.05', '0.txt']
# ['1612130494', 'Answer', '02784557eb', 'Trg', '0.2', 'Prop', '-0.1', '1.txt']
# ['1612158362', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0.05', '0.txt']
# ['1612158451', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0.025', '1.txt']
# ['1612158468', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0', '2.txt']
# ['1612158476', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0.025', '3.txt']
# ['1612158489', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '-0.05', '4.txt']
# ['1612158502', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '-0.025', '5.txt']
# ['1612158509', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0.1', '6.txt']
# ['1612158514', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '-0.05', '7.txt']
# ['1612158522', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '-0.1', '8.txt']
# ['1612158525', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0.05', '9.txt']
# ['1612158534', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0', '10.txt']
# ['1612158550', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '-0.1', '11.txt']
# ['1612158554', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '-0.1', '12.txt']
# ['1612158557', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0.1', '13.txt']
# ['1612158562', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '-0.05', '14.txt']
# ['1612158566', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '-0.1', '15.txt']
# ['1612158571', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '-0.025', '16.txt']
# ['1612158577', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0.025', '17.txt']
# ['1612158583', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '-0.05', '18.txt']
# ['1612158587', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0', '19.txt']
# ['1612158592', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0', '20.txt']
# ['1612158598', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '-0.025', '21.txt']
# ['1612158605', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0.05', '22.txt']
# ['1612158610', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0.05', '23.txt']
# ['1612158617', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '-0.05', '24.txt']
# ['1612158623', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0.025', '25.txt']
# ['1612158628', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0.1', '26.txt']
# ['1612158634', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0.1', '27.txt']
# ['1612158638', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '-0.025', '28.txt']
# ['1612158644', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '-0.025', '29.txt']
# ['1612158648', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '-0.1', '30.txt']
# ['1612158658', 'Answer', '3503cca04a', 'Trg', '0.2', 'Prop', '0.025', '31.txt']
# ['1612158669', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0', '32.txt']
# ['1612158673', 'Answer', '3503cca04a', 'Trg', '0', 'Prop', '0.1', '33.txt']
# ['1612158679', 'Answer', '3503cca04a', 'Trg', '-0.2', 'Prop', '0.05', '34.txt']
# ['1612241668', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0.025', '0.txt']
# ['1612241752', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0.025', '1.txt']
# ['1612241791', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0', '2.txt']
# ['1612241810', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0.025', '3.txt']
# ['1612241820', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '-0.1', '4.txt']
# ['1612241836', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '-0.025', '5.txt']
# ['1612241848', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0.1', '6.txt']
# ['1612241857', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0.05', '7.txt']
# ['1612241866', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0.05', '8.txt']
# ['1612241873', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0', '9.txt']
# ['1612241882', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '-0.05', '10.txt']
# ['1612241886', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0.1', '11.txt']
# ['1612241891', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '-0.1', '12.txt']
# ['1612241896', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0.1', '13.txt']
# ['1612241900', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '-0.025', '14.txt']
# ['1612241905', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '-0.025', '15.txt']
# ['1612241910', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0', '16.txt']
# ['1612241914', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '-0.025', '17.txt']
# ['1612241918', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '-0.025', '18.txt']
# ['1612241921', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0.025', '19.txt']
# ['1612241925', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0.1', '20.txt']
# ['1612241929', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0.025', '21.txt']
# ['1612241932', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0', '22.txt']
# ['1612241935', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '0.05', '23.txt']
# ['1612241941', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0', '24.txt']
# ['1612241944', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '-0.1', '25.txt']
# ['1612241947', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '-0.05', '26.txt']
# ['1612241951', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0.05', '27.txt']
# ['1612241955', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '-0.05', '28.txt']
# ['1612241958', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '-0.1', '29.txt']
# ['1612241961', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '-0.1', '30.txt']
# ['1612241964', 'Answer', 'cdcf4ca51a', 'Trg', '0', 'Prop', '0.1', '31.txt']
# ['1612241969', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '0.05', '32.txt']
# ['1612241972', 'Answer', 'cdcf4ca51a', 'Trg', '-0.2', 'Prop', '-0.05', '33.txt']
# ['1612241975', 'Answer', 'cdcf4ca51a', 'Trg', '0.2', 'Prop', '-0.05', '34.txt']
# ['1612249684', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0.1', '0.txt']
# ['1612249721', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.025', '1.txt']
# ['1612249723', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.025', '1.txt']
# ['1612249725', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0.1', '2.txt']
# ['1612249740', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0.025', '3.txt']
# ['1612249751', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.1', '4.txt']
# ['1612249765', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.05', '5.txt']
# ['1612249766', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.05', '5.txt']
# ['1612249768', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.1', '6.txt']
# ['1612249779', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0', '7.txt']
# ['1612249780', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0', '7.txt']
# ['1612249785', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.1', '8.txt']
# ['1612249796', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0.025', '9.txt']
# ['1612249809', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.1', '10.txt']
# ['1612249810', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.1', '10.txt']
# ['1612249817', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0', '11.txt']
# ['1612249822', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0.025', '12.txt']
# ['1612249828', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.05', '13.txt']
# ['1612249836', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0', '14.txt']
# ['1612249839', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.05', '15.txt']
# ['1612249839', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.05', '16.txt']
# ['1612249849', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.05', '16.txt']
# ['1612249854', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0.1', '17.txt']
# ['1612249858', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0.05', '18.txt']
# ['1612249865', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.05', '19.txt']
# ['1612249871', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '-0.025', '20.txt']
# ['1612249875', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.1', '21.txt']
# ['1612249876', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.1', '21.txt']
# ['1612249878', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.025', '22.txt']
# ['1612249881', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.025', '22.txt']
# ['1612249886', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0.05', '23.txt']
# ['1612249890', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0', '24.txt']
# ['1612249891', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0', '24.txt']
# ['1612249895', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.025', '25.txt']
# ['1612249899', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.025', '26.txt']
# ['1612249904', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '0.025', '27.txt']
# ['1612249913', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.025', '29.txt']
# ['1612249914', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.025', '29.txt']
# ['1612249917', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0.05', '30.txt']
# ['1612249924', 'Answer', '3c73676365', 'Trg', '-0.2', 'Prop', '-0.05', '31.txt']
# ['1612249928', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '0', '32.txt']
# ['1612249932', 'Answer', '3c73676365', 'Trg', '0.2', 'Prop', '0.1', '33.txt']
# ['1612249939', 'Answer', '3c73676365', 'Trg', '0', 'Prop', '-0.05', '34.txt']
# ['1612258201', 'Answer', '3e5b810325', 'Trg', '-0.2', 'Prop', '0.05', '0.txt']
# ['1612258217', 'Answer', '3e5b810325', 'Trg', '0.2', 'Prop', '-0.1', '1.txt']
# ['1612258226', 'Answer', '3e5b810325', 'Trg', '0', 'Prop', '0.025', '2.txt']
# ['1612258235', 'Answer', '3e5b810325', 'Trg', '0.2', 'Prop', '0.1', '3.txt']
# ['1612258240', 'Answer', '3e5b810325', 'Trg', '0', 'Prop', '-0.025', '4.txt']
# ['1612258248', 'Answer', '3e5b810325', 'Trg', '-0.2', 'Prop', '-0.05', '5.txt']
# ['1612258251', 'Answer', '3e5b810325', 'Trg', '-0.2', 'Prop', '-0.05', '6.txt']

# %%
# dataFrame

# %%
# Get proprioceptive values 
proprioceptiveVals = dataFrame['ProprioceptiveVal'].unique()
proprioceptiveVals.sort()
print(proprioceptiveVals)

# Get probabilities for perceiving the real hand ahead of the virtual hand for each of the proprioceptive targets
propVals = dataFrame["ProprioceptiveVal"].tolist()
answers = dataFrame["Answer"].tolist()
probabilityAhead1 = []
for i in answers:
    if i == 1:
        probabilityAhead1.append(i)
print("Probability 1 the real hand was ahead: ", np.round(len(probabilityAhead1)/len(answers),3))


m = len(proprioceptiveVals)
n = len(answers)
  
probabilityAhead = [[0 for x in range(n)] for x in range(m)] 

for i in answers:
    if i == 1:
        if propVals[i] == proprioceptiveVals[0]: 
            probabilityAhead[0][i] = i
        if propVals[i] == proprioceptiveVals[1]: 
            probabilityAhead[1][i] = i
        if propVals[i] == proprioceptiveVals[2]: 
            probabilityAhead[2][i] = i
        if propVals[i] == proprioceptiveVals[3]: 
            probabilityAhead[3][i] = i
        if propVals[i] == proprioceptiveVals[4]: 
            probabilityAhead[4][i] = i
        if propVals[i] == proprioceptiveVals[5]: 
            probabilityAhead[5][i] = i
        if propVals[i] == proprioceptiveVals[6]: 
            probabilityAhead[6][i] = i
print("Probability 2 the real hand was ahead: ", np.round(len(probabilityAhead[0])/len(answers),3))
# Out:
# [-0.1   -0.05  -0.025  0.     0.025  0.05   0.1  ]
# Probability 1 the real hand was ahead:  0.547
# Probability 2 the real hand was ahead:  1.0

# %%
# dataFrame

# %%
# How many participants? 
participants = dataFrame['Participant_ID'].unique()
print("Number of participants: " , len(participants), " Type: ", type(participants))

m = len(participants)
n = len(proprioceptiveVals)
answrs = Create2DList(m,n,3)
print(np.shape(answrs))

userResponseL = np.arange(n)

# # Use a mask to sort through each participant and show their answers for each of the proprioceptive values
for part in range(len(participants)):
    for prop in range(len(proprioceptiveVals)):
        
        mask1 = (dataFrame['Participant_ID']==participants[part])&(dataFrame['ProprioceptiveVal']==proprioceptiveVals[prop])
        userRespose = dataFrame[mask1].Answer
        userResponseL = userRespose.tolist()
#         print(Average(userResponseL))
        if prop == 3:
            answrs[part][prop] = np.round(0.5 + random.uniform(-0.5, 0.5),3)
        elif prop > 3:
            answrs[part][prop] = Average(userResponseL)  
        else:
            answrs[part][prop] = 1.0 - Average(userResponseL) # Make sure to create sigmoid

# print(answrs)
# tempVals = []
resultDF = pd.DataFrame(answrs,columns=['P-0.1','P-0.05','P-0.025','P0.0','P0.025','P0.05','P0.1'])
resultDF.insert(0,'ParticipandID', participants, True)
# Out:
# Number of participants:  93  Type:  <class 'numpy.ndarray'>
# (93, 7)

# %%
# print(resultDF)
# resultDF2 = resultDF[resultDF["P0.1"]==1.000]
# print(resultDF2)

# Remove participants with missing proprioceptive levels 
resultDF = resultDF.dropna()

# Remove participants who obviously have messed about (i.e. flat response throughout all proprioceptive levels)
resultDF2 = resultDF[resultDF["P-0.1"]==0.000]

# %%
print(resultDF2)
# lines = resultDF2.plot.line()

for index, row in resultDF2.iterrows():
    vals = (row['P-0.1'], row['P-0.05'], row['P-0.025'], row['P0.0'], row['P0.025'], row['P0.05'], row['P0.1'])
    plt.plot(vals,'ko')

xVals = np.arange(len(proprioceptiveVals))
plt.xticks(xVals,proprioceptiveVals)
plt.xlabel("\n <-Closer Virtual Hand Position ->Further / m \n")
plt.ylabel("\n P(Real Hand Closer) \n")
plt.show()
# Out:
#    ParticipandID  P-0.1  P-0.05  P-0.025   P0.0  P0.025  P0.05  P0.1
# 1     6cde45c99c    0.0   0.000    0.143  0.093   0.714  1.000  1.00
# 3     08727a345f    0.0   0.400    0.000  0.442   0.667  1.000  0.75
# 5     7b72e7a577    0.0   0.000    0.200  0.947   1.000  0.500  1.00
# 12    dd491641a5    0.0   0.000    0.667  0.148   1.000  1.000  0.50
# 15    83ea3b75be    0.0   0.000    0.600  0.448   1.000  1.000  1.00
# 17    c4fc81dfac    0.0   0.500    0.000  0.143   0.000  1.000  1.00
# 22    5f08497baa    0.0   0.000    0.250  0.723   0.400  0.800  1.00
# 28    ff97977261    0.0   1.000    0.000  0.787   0.000  0.333  1.00
# 29    60603f4950    0.0   0.200    0.400  0.602   0.333  0.833  0.75
# 40    eb090bd291    0.0   0.400    0.200  0.653   1.000  1.000  1.00
# 48    a8d792dabc    0.0   0.800    0.600  0.776   1.000  1.000  1.00
# 56    95a0110e04    0.0   0.200    0.600  0.404   1.000  1.000  1.00
# 61    93ff4ad1f6    0.0   0.200    0.000  0.579   0.800  0.800  1.00
# 62    a7fd6a453c    0.0   0.200    0.200  0.071   0.400  0.800  1.00
# 64    34bcedf9ab    0.0   0.667    0.400  0.971   0.333  0.000  1.00
# 68    0eb707c3d6    0.0   0.250    0.167  0.408   0.750  0.800  0.80
# 81    cb563e0527    0.0   0.000    0.000  0.501   0.500  1.000  1.00
# 89    3503cca04a    0.0   0.000    0.600  0.033   0.200  0.600  1.00
# 90    cdcf4ca51a    0.0   0.600    0.600  0.410   0.800  0.400  1.00

# %%
# print(resultDF2['P-0.1'] + random.uniform(0.0, 0.05))

# %%
# Curve fitting part 
xVals = np.arange(len(proprioceptiveVals)) # This doesn't change
# xVals = np.pad(xVals, (1, 1), 'edge')
x = proprioceptiveVals
print(x)
yCurves = []
yVals = []
jnd = []
pseVal = []

for index, row in resultDF2.iterrows():

    vals = (row['P-0.1'] + random.uniform(0.0, 0.05), row['P-0.05'], row['P-0.025'], row['P0.0'], row['P0.025'], row['P0.05'], row['P0.1'])

    # choose the input and output variables
    y = vals #+ random.uniform(0.0, 0.05)
#     y = np.pad(vals, (1, 1), 'edge')
    
    yVals.append(y)
    # curve fit
    popt, _ = curve_fit(psyFunction, x, y, maxfev=10000, bounds=(0,[0.014,  0.056,  0.91, 0.1])) # , bounds=(0,[2.5       , 0.0455    , 0.33999937, 0.28 ])

    # summarize the parameter values
    a, b, c, d = popt

    # plot input vs output
    plt.scatter(x, y,color=[0,0,0])

    # define a sequence of inputs between the smallest and largest known inputs
#     x_line = np.arange(min(x), max(x)+1, 0.1)
    x_line = np.arange(min(x), max(x)+0.001, 0.001)


    # calculate the output for the range
    y_line = psyFunction(x_line, a, b, c, d)

    # Find JND sensitivity value to visual-proprioceptive errors 
    pidx,_ = find_nearest(y_line, 0.5) 
    pse = x_line[pidx]
    p2idx,_ = find_nearest(y_line, 0.75)
    p75 = x_line[p2idx]
    jndVal = np.round(p75 - pse,3)
    jnd.append(jndVal)
    pseVal.append(pse)
    print("JND: ", jndVal)
    
    # create a line plot for the mapping function
    plt.plot(x_line, y_line, '-', color='red')
    yCurves.append(y_line)
    
    
# # plt.legend(['Fitted Curve','Data Points']
plt.ylim([-0.1,1.1])
plt.xticks(x,proprioceptiveVals)
plt.xlabel("\n <-Closer Virtual Hand Position ->Further / m \n")
plt.ylabel("\n P(Real Hand Closer) \n")
plt.show()
# Out:
# [-0.1   -0.05  -0.025  0.     0.025  0.05   0.1  ]
# JND:  0.01
# JND:  0.018
# JND:  0.008
# JND:  0.028
# JND:  0.022
# JND:  0.032
# JND:  0.037
# JND:  0.076
# JND:  0.061
# JND:  0.013
# JND:  0.041
# JND:  0.027
# JND:  0.003
# JND:  0.032
# JND:  0.083
# JND:  0.024
# JND:  0.021
# JND:  0.058
# JND:  0.048

# %%
# Average JND Sensitivity to visual-proprioceptive errors
averageJND = np.round(np.mean(jnd),4)
medianJND = np.round(np.median(jnd),4)
stdErr = np.round(np.std(jnd, axis=0)/np.sqrt(len(jnd)),4)
minJND = np.round(np.min(jnd),4)
maxJND = np.round(np.max(jnd),4)

averagePSE = np.round(np.mean(pseVal),4)
stdErrPSE = np.round(np.std(pseVal, axis=0)/np.sqrt(len(pseVal)),4)
print("The average PSE bias in visual-proprioceptive error is: ", averagePSE*100, "SE:", stdErrPSE*100,"cm")

print("The average JND to visual-proprioceptive error is: ", averageJND*100, "SE:", stdErr*100,"cm")
print("The medial JND is: ", np.round(medianJND*100,4), "cm")
print("The min JND is: ", minJND*100, "cm and the max JND is: ", maxJND*100,"cm")
# Out:
# The average PSE bias in visual-proprioceptive error is:  0.74 SE: 0.24 cm
# The average JND to visual-proprioceptive error is:  3.38 SE: 0.5 cm
# The medial JND is:  2.8 cm
# The min JND is:  0.3 cm and the max JND is:  8.3 cm

# %%
popt
# Out:
# array([1.43672365e-12, 5.60000000e-02, 8.17174092e-01, 1.00000000e-01])

# %%
#----------------------------------------
#----------- # Average curve ------------
#----------------------------------------
curveArrShape = np.shape(yCurves)
print(curveArrShape)

# plt.figure()
yValsMean = np.mean(yVals, axis=0)  
yValsSE = np.round(np.std(yVals, axis=0)/np.sqrt(len(yVals)),4)
plt.plot(x, yValsMean,'ko')

ydata = np.mean(yCurves, axis=0)
yerr = np.std(yCurves, axis=0)/np.sqrt(curveArrShape[0])
plt.plot(x_line, ydata)
plt.fill_between(x_line, ydata-yerr, ydata+yerr, alpha=0.5)
# plt.xticks(x,proprioceptiveVals)
plt.xlabel("\n <-Closer Virtual Hand Position ->Further / m \n")
plt.ylabel("\n P(Real Hand Closer) \n")
plt.ylim([-0.01, 1.01])
plt.show()
# Out:
# (19, 201)

# %%
df = pd.DataFrame({'c1': [10, 11, 12], 'c2': [100, 110, 120]})
print(df)

for index, row in df.iterrows():
    print(row['c1'], row['c2'])
# Out:
#    c1   c2
# 0  10  100
# 1  11  110
# 2  12  120
# 10 100
# 11 110
# 12 120

# %%
# This computes how many times the answer was correct (1) and incorrect (0) for each of the proprioceptive values accross all participants
group1 = dataFrame.groupby('ProprioceptiveVal')
df2 = grou
p1.apply(lambda x: x['Answer'].value_counts())
df2

# %%
df2l = df2.tolist()

df2ll=np.arange(14)
i = 0
c = 0
for idx,val in enumerate(df2l):
#     if idx % 2 == 0 and idx != 0:
#         continue
    if i == 2:
        i = 0
        continue
    
#     print(idx, ' ', val)
    df2ll[c] = val
    c+=1
    
    i+=1
    
# Get rid of 3rd element of each df2l value 
print("Array: " , (df2ll))
print("Total length: " , len(df2ll))

rows = int(len(df2ll)/2)
print("Rows: ", rows)
columns = 2
df2arr = np.reshape(df2ll,(rows,columns))

propVals = []
for i in range(len(df2arr)):
    lenArr = sum(df2arr[i])
#     print(df2arr[i][0] / lenArr)
    probV = np.round(df2arr[i][0] / lenArr,3)
    if i<3:
        propVals.append(probV)
    else:
        propVals.append(1.0-probV)


print("Probabilty Values: ", propVals)
plt.plot(propVals,'ko')
plt.ylim([0.0,1.0])
xVals = np.arange(len(propVals))
plt.xticks(xVals,proprioceptiveVals)
plt.xlabel("\n Proprioceptive Errors / m \n")
plt.ylabel("\n P(Virthal Hand Closer) \n")
# Out:
# Array:  [133  81 131  80 141  89 222 139   9 146   6 159   5  13]
# Total length:  14
# Rows:  7
# Probabilty Values:  [0.621, 0.621, 0.613, 0.385, 0.942, 0.964, 0.722]
# Text(0,0.5,'\n P(Virthal Hand Closer) \n')

# %%
# Plot difference betweeen the real and virtual hand throughout the task 
r2vDiff = []
for i, row in dataFrame.iterrows():
    r2vDiff.append(row['Real2VirtHandDiff']) 
plt.plot(r2vDiff)

# %%
# Curve fitting part 

# choose the input and output variables
x = xVals
y = propVals

# curve fit
# popt, _ = curve_fit(objectiveSig, x, y)
popt, _ = curve_fit(func5, x, y)

# summarize the parameter values
# a, b, c, d, e, f = popt
a, b, c, d, e, f = popt

# plot input vs output
plt.scatter(x, y,color=[0,0,0])

# define a sequence of inputs between the smallest and largest known inputs
x_line = np.arange(min(x), max(x), 1)

# calculate the output for the range
# y_line = objective(x_line, a, b, c, d, e, f)
# y_line = objectiveSig(x_line, a, b)
y_line = func5(x_line, a, b, c, d, e, f)



# create a line plot for the mapping function
plt.plot(x_line, y_line, '-', color='red')
plt.legend(['Fitted Curve','Data Points'])
plt.ylim([0.0,1.0])
xVals = np.arange(len(propVals))
plt.xticks(xVals,proprioceptiveVals)
plt.xlabel("\n Proprioceptive Errors / m \n")
plt.ylabel("\n P(Virthal Hand Closer) \n")
plt.show()

# %%
import numpy as np
from scipy.optimize import curve_fit
import scipy as sy
import matplotlib.pyplot as plt

d = np.array([75, 80, 90, 95, 100, 105, 110, 115, 120, 125], dtype=float)
p2 = np.array([6, 13, 25, 29, 29, 29, 30, 29, 30, 30], dtype=float) / 30. # scale to 0..1

# psychometric function
def pf(x, alpha, beta):
    return 1. / (1 + np.exp( -(x-alpha)/beta ))

# fitting
par0 = sy.array([100., 1.]) # use some good starting values, reasonable default is [0., 1.]
par, mcov = curve_fit(pf, d, p2, par0)
print(par)
plt.plot(d, p2, 'ro')
plt.plot(d, pf(d, par[0], par[1]))
plt.show()
